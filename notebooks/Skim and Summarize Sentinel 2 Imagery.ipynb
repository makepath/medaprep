# %% [markdown]
# # Skimming large amounts of Sentinel 2 data
# In this notebook, we will show how using `geolt.skim` and `geolt.summarize` can help prepare and visualize large sets of data. We will load a large set of Sentinel-2 imagery over Austin, TX and quickly retreive statistics about the features within to assist with downstream processing. We will use the following process:
# 1. Initialize Dask cluster to load `xarray Dataset` from a public S3 bucket.
# 2. `skim` the dataset for a quick set of summary statistics.
# 3. `summarize` features within the dataset to assist with feature engineering and downstream use.

# %%
from porcupine import skim, visualize, query
import pandas as pd
import xarray
import dask.distributed
from odc.stac import configure_rio, stac_load
from pystac_client import Client
import folium
import folium.plugins
import geopandas as gpd
import shapely.geometry
from IPython.display import HTML, display

client = dask.distributed.Client()
configure_rio(cloud_defaults=True, aws={"aws_unsigned": True}, client=client)
display(client)
# Out:
# /Users/dylan/opt/anaconda3/envs/odc-stac/lib/python3.10/site-packages/distributed/node.py:179: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 65431 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:65432' processes=4 threads=8, memory=16.00 GiB>

# %% [markdown]
# ## Load Dataset from STAC catalog
# The following cell loads an `xarray Dataset` containing Sentinel-2 imagery from a STAC catalog. We initialize the center point of our query to be the center of Austin, TX and search for imagery from July, 2022 within a 100 km radius.

# %%
config = {
    "sentinel-s2-l2a-cogs": {
        "assets": {
            "*": {"data_type": "uint16", "nodata": 0},
            "SCL": {"data_type": "uint8", "nodata": 0},
            "visual": {"data_type": "uint8", "nodata": 0},
        },
        "aliases": {"red": "B04", "green": "B03", "blue": "B02"},
    },
    "*": {"warnings": "ignore"},
}
km2deg = 1.0 / 111
x, y = (-97.744, 30.266)
r = 100 * km2deg
bbox = (x - r, y - r, x + r, y + r)
catalog = Client.open("https://earth-search.aws.element84.com/v0")
query = catalog.search(
    collections=["sentinel-s2-l2a-cogs"], datetime="2022-07-01/2022-07-31", limit=100, bbox=bbox
)
items = list(query.get_items())
stac_json = query.get_all_items_as_dict()

crs = "epsg:3857"
zoom = 2**5 # overview level 5

data = stac_load(
    items,
    crs=crs,
    resolution=10*zoom,
    chunks={},
    groupby="solar_day",
    stac_cfg=config,
)
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 1142, x: 1137, time: 2)
# Coordinates:
#   * y            (y) float64 3.716e+06 3.715e+06 ... 3.351e+06 3.351e+06
#   * x            (x) float64 -1.102e+07 -1.102e+07 ... -1.066e+07 -1.066e+07
#     spatial_ref  int32 3857
#   * time         (time) datetime64[ns] 2022-07-28T17:25:14 2022-07-30T17:15:20
# Data variables: (12/16)
#     visual       (time, y, x) uint8 dask.array<chunksize=(1, 1142, 1137), meta=np.ndarray>
#     B01          (time, y, x) uint16 dask.array<chunksize=(1, 1142, 1137), meta=np.ndarray>
#     B02          (time, y, x) uint16 dask.array<chunksize=(1, 1142, 1137), meta=np.ndarray>
#     B03          (time, y, x) uint16 dask.array<chunksize=(1, 1142, 1137), meta=np.ndarray>
#     B04          (time, y, x) uint16 dask.array<chunksize=(1, 1142, 1137), meta=np.ndarray>
#     B05          (time, y, x) uint16 dask.array<chunksize=(1, 1142, 1137), meta=np.ndarray>
#     ...           ...
#     B09          (time, y, x) uint16 dask.array<chunksize=(1, 1142, 1137), meta=np.ndarray>
#     B11          (time, y, x) uint16 dask.array<chunksize=(1, 1142, 1137), meta=np.ndarray>
#     B12          (time, y, x) uint16 dask.array<chunksize=(1, 1142, 1137), meta=np.ndarray>
#     AOT          (time, y, x) uint16 dask.array<chunksize=(1, 1142, 1137), meta=np.ndarray>
#     WVP          (time, y, x) uint16 dask.array<chunksize=(1, 1142, 1137), meta=np.ndarray>
#     SCL          (time, y, x) uint8 dask.array<chunksize=(1, 1142, 1137), meta=np.ndarray>

# %%
stac_json
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'stac_version': '1.0.0-beta.2',
#    'stac_extensions': ['eo', 'view', 'proj'],
#    'id': 'S2A_14RNT_20220730_0_L2A',
#    'bbox': [-98.24017654176154,
#     28.834781500810376,
#     -97.86379644637883,
#     29.82659734364876],
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.87472854105172, 28.834781500810376],
#       [-98.24017654176154, 28.837334879225125],
#       [-97.99000597196367, 29.82659734364876],
#       [-97.86379644637883, 29.82557210301281],
#       [-97.87472854105172, 28.834781500810376]]]},
#    'properties': {'datetime': '2022-07-30T17:15:56Z',
#     'platform': 'sentinel-2a',
#     'constellation': 'sentinel-2',
#     'instruments': ['msi'],
#     'gsd': 10,
#     'view:off_nadir': 0,
#     'proj:epsg': 32614,
#     'sentinel:utm_zone': 14,
#     'sentinel:latitude_band': 'R',
#     'sentinel:grid_square': 'NT',
#     'sentinel:sequence': '0',
#     'sentinel:product_id': 'S2A_MSIL2A_20220730T165901_N0400_R069_T14RNT_20220731T144302',
#     'sentinel:data_coverage': 21.79,
#     'eo:cloud_cover': 0,
#     'sentinel:valid_cloud_cover': True,
#     'sentinel:processing_baseline': '04.00',
#     'sentinel:boa_offset_applied': True,
#     'created': '2022-07-31T19:25:18.048Z',
#     'updated': '2022-07-31T19:25:18.048Z'},
#    'collection': 'sentinel-s2-l2a-cogs',
#    'assets': {'thumbnail': {'title': 'Thumbnail',
#      'type': 'image/png',
#      'roles': ['thumbnail'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/14/R/NT/2022/7/30/0/preview.jpg'},
#     'overview': {'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['overview'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038},
#       {'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045},
#       {'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/L2A_PVI.tif',
#      'proj:shape': [343, 343],
#      'proj:transform': [320, 0, 499980, 0, -320, 3300000, 0, 0, 1]},
#     'info': {'title': 'Original JSON metadata',
#      'type': 'application/json',
#      'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/14/R/NT/2022/7/30/0/tileInfo.json'},
#     'metadata': {'title': 'Original XML metadata',
#      'type': 'application/xml',
#      'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/14/R/NT/2022/7/30/0/metadata.xml'},
#     'visual': {'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['overview'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038},
#       {'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045},
#       {'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/TCI.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3300000, 0, 0, 1]},
#     'B01': {'title': 'Band 1 (coastal)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 60,
#      'eo:bands': [{'name': 'B01',
#        'common_name': 'coastal',
#        'center_wavelength': 0.4439,
#        'full_width_half_max': 0.027}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/B01.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 499980, 0, -60, 3300000, 0, 0, 1]},
#     'B02': {'title': 'Band 2 (blue)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/B02.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3300000, 0, 0, 1]},
#     'B03': {'title': 'Band 3 (green)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/B03.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3300000, 0, 0, 1]},
#     'B04': {'title': 'Band 4 (red)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/B04.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3300000, 0, 0, 1]},
#     'B05': {'title': 'Band 5',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B05',
#        'center_wavelength': 0.7039,
#        'full_width_half_max': 0.019}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/B05.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3300000, 0, 0, 1]},
#     'B06': {'title': 'Band 6',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B06',
#        'center_wavelength': 0.7402,
#        'full_width_half_max': 0.018}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/B06.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3300000, 0, 0, 1]},
#     'B07': {'title': 'Band 7',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B07',
#        'center_wavelength': 0.7825,
#        'full_width_half_max': 0.028}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/B07.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3300000, 0, 0, 1]},
#     'B08': {'title': 'Band 8 (nir)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B08',
#        'common_name': 'nir',
#        'center_wavelength': 0.8351,
#        'full_width_half_max': 0.145}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/B08.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3300000, 0, 0, 1]},
#     'B8A': {'title': 'Band 8A',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B8A',
#        'center_wavelength': 0.8648,
#        'full_width_half_max': 0.033}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/B8A.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3300000, 0, 0, 1]},
#     'B09': {'title': 'Band 9',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 60,
#      'eo:bands': [{'name': 'B09',
#        'center_wavelength': 0.945,
#        'full_width_half_max': 0.026}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/B09.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 499980, 0, -60, 3300000, 0, 0, 1]},
#     'B11': {'title': 'Band 11 (swir16)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B11',
#        'common_name': 'swir16',
#        'center_wavelength': 1.6137,
#        'full_width_half_max': 0.143}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/B11.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3300000, 0, 0, 1]},
#     'B12': {'title': 'Band 12 (swir22)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B12',
#        'common_name': 'swir22',
#        'center_wavelength': 2.22024,
#        'full_width_half_max': 0.242}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/B12.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3300000, 0, 0, 1]},
#     'AOT': {'title': 'Aerosol Optical Thickness (AOT)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/AOT.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 499980, 0, -60, 3300000, 0, 0, 1]},
#     'WVP': {'title': 'Water Vapour (WVP)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/WVP.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3300000, 0, 0, 1]},
#     'SCL': {'title': 'Scene Classification Map (SCL)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/SCL.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3300000, 0, 0, 1]}},
#    'links': [{'rel': 'self',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_14RNT_20220730_0_L2A'},
#     {'rel': 'canonical',
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/S2A_14RNT_20220730_0_L2A.json',
#      'type': 'application/json'},
#     {'title': 'sentinel-s2-l2a-aws/workflow-publish-sentinel/tiles-14-R-NT-2022-7-30-0',
#      'rel': 'via-cirrus',
#      'href': 'https://cirrus-earth-search.aws.element84.com/v0/catid/sentinel-s2-l2a-aws/workflow-publish-sentinel/tiles-14-R-NT-2022-7-30-0'},
#     {'title': 'Source STAC Item',
#      'rel': 'derived_from',
#      'href': 'https://cirrus-v0-data-1qm7gekzjucbq.s3.us-west-2.amazonaws.com/sentinel-s2-l2a/14/R/NT/2022/7/S2A_14RNT_20220730_0_L2A/S2A_14RNT_20220730_0_L2A.json',
#      'type': 'application/json'},
#     {'title': 'sentinel-s2-l2a/workflow-cog-archive/S2A_14RNT_20220730_0_L2A',
#      'rel': 'via-cirrus',
#      'href': 'https://cirrus-earth-search.aws.element84.com/v0/catid/sentinel-s2-l2a/workflow-cog-archive/S2A_14RNT_20220730_0_L2A'},
#     {'rel': 'parent',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'collection',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'root', 'href': 'https://earth-search.aws.element84.com/v0/'}]},
#   {'type': 'Feature',
#    'stac_version': '1.0.0-beta.2',
#    'stac_extensions': ['eo', 'view', 'proj'],
#    'id': 'S2A_14RPT_20220730_0_L2A',
#    'bbox': [-97.97494244101736,
#     28.822340288958415,
#     -96.82906983233377,
#     29.82640366190293],
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-96.84994334611872, 28.822340288958415],
#       [-97.97494244101736, 28.835580215062794],
#       [-97.96498348950838, 29.82640366190293],
#       [-96.82906983233377, 29.812619352753874],
#       [-96.84994334611872, 28.822340288958415]]]},
#    'properties': {'datetime': '2022-07-30T17:15:52Z',
#     'platform': 'sentinel-2a',
#     'constellation': 'sentinel-2',
#     'instruments': ['msi'],
#     'gsd': 10,
#     'view:off_nadir': 0,
#     'proj:epsg': 32614,
#     'sentinel:utm_zone': 14,
#     'sentinel:latitude_band': 'R',
#     'sentinel:grid_square': 'PT',
#     'sentinel:sequence': '0',
#     'sentinel:product_id': 'S2A_MSIL2A_20220730T165901_N0400_R069_T14RPT_20220731T144302',
#     'sentinel:data_coverage': 100,
#     'eo:cloud_cover': 8.71,
#     'sentinel:valid_cloud_cover': True,
#     'sentinel:processing_baseline': '04.00',
#     'sentinel:boa_offset_applied': True,
#     'created': '2022-07-31T20:23:18.094Z',
#     'updated': '2022-07-31T20:23:18.094Z'},
#    'collection': 'sentinel-s2-l2a-cogs',
#    'assets': {'thumbnail': {'title': 'Thumbnail',
#      'type': 'image/png',
#      'roles': ['thumbnail'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/14/R/PT/2022/7/30/0/preview.jpg'},
#     'overview': {'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['overview'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038},
#       {'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045},
#       {'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/L2A_PVI.tif',
#      'proj:shape': [343, 343],
#      'proj:transform': [320, 0, 600000, 0, -320, 3300000, 0, 0, 1]},
#     'info': {'title': 'Original JSON metadata',
#      'type': 'application/json',
#      'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/14/R/PT/2022/7/30/0/tileInfo.json'},
#     'metadata': {'title': 'Original XML metadata',
#      'type': 'application/xml',
#      'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/14/R/PT/2022/7/30/0/metadata.xml'},
#     'visual': {'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['overview'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038},
#       {'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045},
#       {'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/TCI.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 600000, 0, -10, 3300000, 0, 0, 1]},
#     'B01': {'title': 'Band 1 (coastal)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 60,
#      'eo:bands': [{'name': 'B01',
#        'common_name': 'coastal',
#        'center_wavelength': 0.4439,
#        'full_width_half_max': 0.027}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/B01.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 600000, 0, -60, 3300000, 0, 0, 1]},
#     'B02': {'title': 'Band 2 (blue)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/B02.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 600000, 0, -10, 3300000, 0, 0, 1]},
#     'B03': {'title': 'Band 3 (green)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/B03.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 600000, 0, -10, 3300000, 0, 0, 1]},
#     'B04': {'title': 'Band 4 (red)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/B04.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 600000, 0, -10, 3300000, 0, 0, 1]},
#     'B05': {'title': 'Band 5',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B05',
#        'center_wavelength': 0.7039,
#        'full_width_half_max': 0.019}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/B05.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3300000, 0, 0, 1]},
#     'B06': {'title': 'Band 6',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B06',
#        'center_wavelength': 0.7402,
#        'full_width_half_max': 0.018}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/B06.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3300000, 0, 0, 1]},
#     'B07': {'title': 'Band 7',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B07',
#        'center_wavelength': 0.7825,
#        'full_width_half_max': 0.028}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/B07.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3300000, 0, 0, 1]},
#     'B08': {'title': 'Band 8 (nir)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B08',
#        'common_name': 'nir',
#        'center_wavelength': 0.8351,
#        'full_width_half_max': 0.145}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/B08.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 600000, 0, -10, 3300000, 0, 0, 1]},
#     'B8A': {'title': 'Band 8A',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B8A',
#        'center_wavelength': 0.8648,
#        'full_width_half_max': 0.033}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/B8A.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3300000, 0, 0, 1]},
#     'B09': {'title': 'Band 9',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 60,
#      'eo:bands': [{'name': 'B09',
#        'center_wavelength': 0.945,
#        'full_width_half_max': 0.026}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/B09.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 600000, 0, -60, 3300000, 0, 0, 1]},
#     'B11': {'title': 'Band 11 (swir16)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B11',
#        'common_name': 'swir16',
#        'center_wavelength': 1.6137,
#        'full_width_half_max': 0.143}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/B11.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3300000, 0, 0, 1]},
#     'B12': {'title': 'Band 12 (swir22)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B12',
#        'common_name': 'swir22',
#        'center_wavelength': 2.22024,
#        'full_width_half_max': 0.242}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/B12.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3300000, 0, 0, 1]},
#     'AOT': {'title': 'Aerosol Optical Thickness (AOT)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/AOT.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 600000, 0, -60, 3300000, 0, 0, 1]},
#     'WVP': {'title': 'Water Vapour (WVP)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/WVP.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 600000, 0, -10, 3300000, 0, 0, 1]},
#     'SCL': {'title': 'Scene Classification Map (SCL)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/SCL.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3300000, 0, 0, 1]}},
#    'links': [{'rel': 'self',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_14RPT_20220730_0_L2A'},
#     {'rel': 'canonical',
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/S2A_14RPT_20220730_0_L2A.json',
#      'type': 'application/json'},
#     {'title': 'sentinel-s2-l2a-aws/workflow-publish-sentinel/tiles-14-R-PT-2022-7-30-0',
#      'rel': 'via-cirrus',
#      'href': 'https://cirrus-earth-search.aws.element84.com/v0/catid/sentinel-s2-l2a-aws/workflow-publish-sentinel/tiles-14-R-PT-2022-7-30-0'},
#     {'title': 'Source STAC Item',
#      'rel': 'derived_from',
#      'href': 'https://cirrus-v0-data-1qm7gekzjucbq.s3.us-west-2.amazonaws.com/sentinel-s2-l2a/14/R/PT/2022/7/S2A_14RPT_20220730_0_L2A/S2A_14RPT_20220730_0_L2A.json',
#      'type': 'application/json'},
#     {'title': 'sentinel-s2-l2a/workflow-cog-archive/S2A_14RPT_20220730_0_L2A',
#      'rel': 'via-cirrus',
#      'href': 'https://cirrus-earth-search.aws.element84.com/v0/catid/sentinel-s2-l2a/workflow-cog-archive/S2A_14RPT_20220730_0_L2A'},
#     {'rel': 'parent',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'collection',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'root', 'href': 'https://earth-search.aws.element84.com/v0/'}]},
#   {'type': 'Feature',
#    'stac_version': '1.0.0-beta.2',
#    'stac_extensions': ['eo', 'view', 'proj'],
#    'id': 'S2A_14RQT_20220730_0_L2A',
#    'bbox': [-96.95071041802514,
#     28.8021464220105,
#     -95.79584839823261,
#     29.814252353255014],
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.82662209756289, 28.8021464220105],
#       [-96.95071041802514, 28.823908804677075],
#       [-96.93081345146632, 29.814252353255014],
#       [-95.79584839823261, 29.791595456480714],
#       [-95.82662209756289, 28.8021464220105]]]},
#    'properties': {'datetime': '2022-07-30T17:15:49Z',
#     'platform': 'sentinel-2a',
#     'constellation': 'sentinel-2',
#     'instruments': ['msi'],
#     'gsd': 10,
#     'view:off_nadir': 0,
#     'proj:epsg': 32614,
#     'sentinel:utm_zone': 14,
#     'sentinel:latitude_band': 'R',
#     'sentinel:grid_square': 'QT',
#     'sentinel:sequence': '0',
#     'sentinel:product_id': 'S2A_MSIL2A_20220730T165901_N0400_R069_T14RQT_20220731T144302',
#     'sentinel:data_coverage': 100,
#     'eo:cloud_cover': 85.35,
#     'sentinel:valid_cloud_cover': True,
#     'sentinel:processing_baseline': '04.00',
#     'sentinel:boa_offset_applied': True,
#     'created': '2022-07-31T19:51:10.772Z',
#     'updated': '2022-07-31T19:51:10.772Z'},
#    'collection': 'sentinel-s2-l2a-cogs',
#    'assets': {'thumbnail': {'title': 'Thumbnail',
#      'type': 'image/png',
#      'roles': ['thumbnail'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/14/R/QT/2022/7/30/0/preview.jpg'},
#     'overview': {'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['overview'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038},
#       {'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045},
#       {'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/L2A_PVI.tif',
#      'proj:shape': [343, 343],
#      'proj:transform': [320, 0, 699960, 0, -320, 3300000, 0, 0, 1]},
#     'info': {'title': 'Original JSON metadata',
#      'type': 'application/json',
#      'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/14/R/QT/2022/7/30/0/tileInfo.json'},
#     'metadata': {'title': 'Original XML metadata',
#      'type': 'application/xml',
#      'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/14/R/QT/2022/7/30/0/metadata.xml'},
#     'visual': {'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['overview'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038},
#       {'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045},
#       {'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/TCI.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 3300000, 0, 0, 1]},
#     'B01': {'title': 'Band 1 (coastal)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 60,
#      'eo:bands': [{'name': 'B01',
#        'common_name': 'coastal',
#        'center_wavelength': 0.4439,
#        'full_width_half_max': 0.027}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/B01.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 699960, 0, -60, 3300000, 0, 0, 1]},
#     'B02': {'title': 'Band 2 (blue)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/B02.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 3300000, 0, 0, 1]},
#     'B03': {'title': 'Band 3 (green)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/B03.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 3300000, 0, 0, 1]},
#     'B04': {'title': 'Band 4 (red)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/B04.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 3300000, 0, 0, 1]},
#     'B05': {'title': 'Band 5',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B05',
#        'center_wavelength': 0.7039,
#        'full_width_half_max': 0.019}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/B05.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 3300000, 0, 0, 1]},
#     'B06': {'title': 'Band 6',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B06',
#        'center_wavelength': 0.7402,
#        'full_width_half_max': 0.018}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/B06.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 3300000, 0, 0, 1]},
#     'B07': {'title': 'Band 7',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B07',
#        'center_wavelength': 0.7825,
#        'full_width_half_max': 0.028}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/B07.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 3300000, 0, 0, 1]},
#     'B08': {'title': 'Band 8 (nir)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B08',
#        'common_name': 'nir',
#        'center_wavelength': 0.8351,
#        'full_width_half_max': 0.145}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/B08.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 3300000, 0, 0, 1]},
#     'B8A': {'title': 'Band 8A',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B8A',
#        'center_wavelength': 0.8648,
#        'full_width_half_max': 0.033}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/B8A.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 3300000, 0, 0, 1]},
#     'B09': {'title': 'Band 9',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 60,
#      'eo:bands': [{'name': 'B09',
#        'center_wavelength': 0.945,
#        'full_width_half_max': 0.026}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/B09.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 699960, 0, -60, 3300000, 0, 0, 1]},
#     'B11': {'title': 'Band 11 (swir16)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B11',
#        'common_name': 'swir16',
#        'center_wavelength': 1.6137,
#        'full_width_half_max': 0.143}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/B11.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 3300000, 0, 0, 1]},
#     'B12': {'title': 'Band 12 (swir22)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B12',
#        'common_name': 'swir22',
#        'center_wavelength': 2.22024,
#        'full_width_half_max': 0.242}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/B12.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 3300000, 0, 0, 1]},
#     'AOT': {'title': 'Aerosol Optical Thickness (AOT)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/AOT.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 699960, 0, -60, 3300000, 0, 0, 1]},
#     'WVP': {'title': 'Water Vapour (WVP)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/WVP.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 3300000, 0, 0, 1]},
#     'SCL': {'title': 'Scene Classification Map (SCL)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/SCL.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 3300000, 0, 0, 1]}},
#    'links': [{'rel': 'self',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_14RQT_20220730_0_L2A'},
#     {'rel': 'canonical',
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/S2A_14RQT_20220730_0_L2A.json',
#      'type': 'application/json'},
#     {'title': 'sentinel-s2-l2a-aws/workflow-publish-sentinel/tiles-14-R-QT-2022-7-30-0',
#      'rel': 'via-cirrus',
#      'href': 'https://cirrus-earth-search.aws.element84.com/v0/catid/sentinel-s2-l2a-aws/workflow-publish-sentinel/tiles-14-R-QT-2022-7-30-0'},
#     {'title': 'Source STAC Item',
#      'rel': 'derived_from',
#      'href': 'https://cirrus-v0-data-1qm7gekzjucbq.s3.us-west-2.amazonaws.com/sentinel-s2-l2a/14/R/QT/2022/7/S2A_14RQT_20220730_0_L2A/S2A_14RQT_20220730_0_L2A.json',
#      'type': 'application/json'},
#     {'title': 'sentinel-s2-l2a/workflow-cog-archive/S2A_14RQT_20220730_0_L2A',
#      'rel': 'via-cirrus',
#      'href': 'https://cirrus-earth-search.aws.element84.com/v0/catid/sentinel-s2-l2a/workflow-cog-archive/S2A_14RQT_20220730_0_L2A'},
#     {'rel': 'parent',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'collection',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'root', 'href': 'https://earth-search.aws.element84.com/v0/'}]},
#   {'type': 'Feature',
#    'stac_version': '1.0.0-beta.2',
#    'stac_extensions': ['eo', 'view', 'proj'],
#    'id': 'S2A_14RNU_20220730_0_L2A',
#    'bbox': [-98.01239386287828,
#     29.737352799107043,
#     -97.85957911907849,
#     30.337845874602106],
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.86582626780243, 29.737352799107043],
#       [-98.01239386287828, 29.73852775057042],
#       [-97.85957911907849, 30.337845874602106],
#       [-97.86582626780243, 29.737352799107043]]]},
#    'properties': {'datetime': '2022-07-30T17:15:44Z',
#     'platform': 'sentinel-2a',
#     'constellation': 'sentinel-2',
#     'instruments': ['msi'],
#     'gsd': 10,
#     'view:off_nadir': 0,
#     'proj:epsg': 32614,
#     'sentinel:utm_zone': 14,
#     'sentinel:latitude_band': 'R',
#     'sentinel:grid_square': 'NU',
#     'sentinel:sequence': '0',
#     'sentinel:product_id': 'S2A_MSIL2A_20220730T165901_N0400_R069_T14RNU_20220731T144302',
#     'sentinel:data_coverage': 3.91,
#     'eo:cloud_cover': 5.61,
#     'sentinel:valid_cloud_cover': True,
#     'sentinel:processing_baseline': '04.00',
#     'sentinel:boa_offset_applied': True,
#     'created': '2022-07-31T20:11:50.723Z',
#     'updated': '2022-07-31T20:11:50.723Z'},
#    'collection': 'sentinel-s2-l2a-cogs',
#    'assets': {'thumbnail': {'title': 'Thumbnail',
#      'type': 'image/png',
#      'roles': ['thumbnail'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/14/R/NU/2022/7/30/0/preview.jpg'},
#     'overview': {'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['overview'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038},
#       {'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045},
#       {'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/L2A_PVI.tif',
#      'proj:shape': [343, 343],
#      'proj:transform': [320, 0, 499980, 0, -320, 3400020, 0, 0, 1]},
#     'info': {'title': 'Original JSON metadata',
#      'type': 'application/json',
#      'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/14/R/NU/2022/7/30/0/tileInfo.json'},
#     'metadata': {'title': 'Original XML metadata',
#      'type': 'application/xml',
#      'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/14/R/NU/2022/7/30/0/metadata.xml'},
#     'visual': {'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['overview'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038},
#       {'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045},
#       {'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/TCI.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3400020, 0, 0, 1]},
#     'B01': {'title': 'Band 1 (coastal)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 60,
#      'eo:bands': [{'name': 'B01',
#        'common_name': 'coastal',
#        'center_wavelength': 0.4439,
#        'full_width_half_max': 0.027}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/B01.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 499980, 0, -60, 3400020, 0, 0, 1]},
#     'B02': {'title': 'Band 2 (blue)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/B02.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3400020, 0, 0, 1]},
#     'B03': {'title': 'Band 3 (green)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/B03.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3400020, 0, 0, 1]},
#     'B04': {'title': 'Band 4 (red)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/B04.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3400020, 0, 0, 1]},
#     'B05': {'title': 'Band 5',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B05',
#        'center_wavelength': 0.7039,
#        'full_width_half_max': 0.019}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/B05.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3400020, 0, 0, 1]},
#     'B06': {'title': 'Band 6',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B06',
#        'center_wavelength': 0.7402,
#        'full_width_half_max': 0.018}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/B06.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3400020, 0, 0, 1]},
#     'B07': {'title': 'Band 7',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B07',
#        'center_wavelength': 0.7825,
#        'full_width_half_max': 0.028}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/B07.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3400020, 0, 0, 1]},
#     'B08': {'title': 'Band 8 (nir)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B08',
#        'common_name': 'nir',
#        'center_wavelength': 0.8351,
#        'full_width_half_max': 0.145}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/B08.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3400020, 0, 0, 1]},
#     'B8A': {'title': 'Band 8A',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B8A',
#        'center_wavelength': 0.8648,
#        'full_width_half_max': 0.033}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/B8A.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3400020, 0, 0, 1]},
#     'B09': {'title': 'Band 9',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 60,
#      'eo:bands': [{'name': 'B09',
#        'center_wavelength': 0.945,
#        'full_width_half_max': 0.026}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/B09.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 499980, 0, -60, 3400020, 0, 0, 1]},
#     'B11': {'title': 'Band 11 (swir16)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B11',
#        'common_name': 'swir16',
#        'center_wavelength': 1.6137,
#        'full_width_half_max': 0.143}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/B11.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3400020, 0, 0, 1]},
#     'B12': {'title': 'Band 12 (swir22)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B12',
#        'common_name': 'swir22',
#        'center_wavelength': 2.22024,
#        'full_width_half_max': 0.242}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/B12.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3400020, 0, 0, 1]},
#     'AOT': {'title': 'Aerosol Optical Thickness (AOT)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/AOT.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 499980, 0, -60, 3400020, 0, 0, 1]},
#     'WVP': {'title': 'Water Vapour (WVP)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/WVP.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3400020, 0, 0, 1]},
#     'SCL': {'title': 'Scene Classification Map (SCL)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/SCL.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3400020, 0, 0, 1]}},
#    'links': [{'rel': 'self',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_14RNU_20220730_0_L2A'},
#     {'rel': 'canonical',
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NU/2022/7/S2A_14RNU_20220730_0_L2A/S2A_14RNU_20220730_0_L2A.json',
#      'type': 'application/json'},
#     {'title': 'sentinel-s2-l2a-aws/workflow-publish-sentinel/tiles-14-R-NU-2022-7-30-0',
#      'rel': 'via-cirrus',
#      'href': 'https://cirrus-earth-search.aws.element84.com/v0/catid/sentinel-s2-l2a-aws/workflow-publish-sentinel/tiles-14-R-NU-2022-7-30-0'},
# ...
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 499980, 0, -60, 3500040, 0, 0, 1]},
#     'B11': {'title': 'Band 11 (swir16)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B11',
#        'common_name': 'swir16',
#        'center_wavelength': 1.6137,
#        'full_width_half_max': 0.143}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NV/2022/7/S2B_14RNV_20220728_0_L2A/B11.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3500040, 0, 0, 1]},
#     'B12': {'title': 'Band 12 (swir22)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B12',
#        'common_name': 'swir22',
#        'center_wavelength': 2.22024,
#        'full_width_half_max': 0.242}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NV/2022/7/S2B_14RNV_20220728_0_L2A/B12.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3500040, 0, 0, 1]},
#     'AOT': {'title': 'Aerosol Optical Thickness (AOT)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NV/2022/7/S2B_14RNV_20220728_0_L2A/AOT.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 499980, 0, -60, 3500040, 0, 0, 1]},
#     'WVP': {'title': 'Water Vapour (WVP)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NV/2022/7/S2B_14RNV_20220728_0_L2A/WVP.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 499980, 0, -10, 3500040, 0, 0, 1]},
#     'SCL': {'title': 'Scene Classification Map (SCL)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NV/2022/7/S2B_14RNV_20220728_0_L2A/SCL.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 499980, 0, -20, 3500040, 0, 0, 1]}},
#    'links': [{'rel': 'self',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_14RNV_20220728_0_L2A'},
#     {'rel': 'canonical',
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/NV/2022/7/S2B_14RNV_20220728_0_L2A/S2B_14RNV_20220728_0_L2A.json',
#      'type': 'application/json'},
#     {'title': 'sentinel-s2-l2a-aws/workflow-publish-sentinel/tiles-14-R-NV-2022-7-28-0',
#      'rel': 'via-cirrus',
#      'href': 'https://cirrus-earth-search.aws.element84.com/v0/catid/sentinel-s2-l2a-aws/workflow-publish-sentinel/tiles-14-R-NV-2022-7-28-0'},
#     {'title': 'Source STAC Item',
#      'rel': 'derived_from',
#      'href': 'https://cirrus-v0-data-1qm7gekzjucbq.s3.us-west-2.amazonaws.com/sentinel-s2-l2a/14/R/NV/2022/7/S2B_14RNV_20220728_0_L2A/S2B_14RNV_20220728_0_L2A.json',
#      'type': 'application/json'},
#     {'title': 'sentinel-s2-l2a/workflow-cog-archive/S2B_14RNV_20220728_0_L2A',
#      'rel': 'via-cirrus',
#      'href': 'https://cirrus-earth-search.aws.element84.com/v0/catid/sentinel-s2-l2a/workflow-cog-archive/S2B_14RNV_20220728_0_L2A'},
#     {'rel': 'parent',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'collection',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'root', 'href': 'https://earth-search.aws.element84.com/v0/'}]},
#   {'type': 'Feature',
#    'stac_version': '1.0.0-beta.2',
#    'stac_extensions': ['eo', 'view', 'proj'],
#    'id': 'S2B_14RPV_20220728_0_L2A',
#    'bbox': [-97.95640812135858,
#     30.633321650382168,
#     -96.87658617580617,
#     31.631183521278835],
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.16528913181138, 30.633321650382168],
#       [-97.95640812135858, 30.641541309097903],
#       [-97.9455143017511, 31.631183521278835],
#       [-96.87658617580617, 31.617879406628116],
#       [-97.16528913181138, 30.633321650382168]]]},
#    'properties': {'datetime': '2022-07-28T17:25:14Z',
#     'platform': 'sentinel-2b',
#     'constellation': 'sentinel-2',
#     'instruments': ['msi'],
#     'gsd': 10,
#     'view:off_nadir': 0,
#     'proj:epsg': 32614,
#     'sentinel:utm_zone': 14,
#     'sentinel:latitude_band': 'R',
#     'sentinel:grid_square': 'PV',
#     'sentinel:sequence': '0',
#     'sentinel:product_id': 'S2B_MSIL2A_20220728T170859_N0400_R112_T14RPV_20220728T213908',
#     'sentinel:data_coverage': 80.61,
#     'eo:cloud_cover': 0.36,
#     'sentinel:valid_cloud_cover': True,
#     'sentinel:processing_baseline': '04.00',
#     'sentinel:boa_offset_applied': True,
#     'created': '2022-07-29T00:32:05.763Z',
#     'updated': '2022-07-29T00:32:05.763Z'},
#    'collection': 'sentinel-s2-l2a-cogs',
#    'assets': {'thumbnail': {'title': 'Thumbnail',
#      'type': 'image/png',
#      'roles': ['thumbnail'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/14/R/PV/2022/7/28/0/preview.jpg'},
#     'overview': {'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['overview'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038},
#       {'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045},
#       {'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/L2A_PVI.tif',
#      'proj:shape': [343, 343],
#      'proj:transform': [320, 0, 600000, 0, -320, 3500040, 0, 0, 1]},
#     'info': {'title': 'Original JSON metadata',
#      'type': 'application/json',
#      'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/14/R/PV/2022/7/28/0/tileInfo.json'},
#     'metadata': {'title': 'Original XML metadata',
#      'type': 'application/xml',
#      'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/14/R/PV/2022/7/28/0/metadata.xml'},
#     'visual': {'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['overview'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038},
#       {'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045},
#       {'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/TCI.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 600000, 0, -10, 3500040, 0, 0, 1]},
#     'B01': {'title': 'Band 1 (coastal)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 60,
#      'eo:bands': [{'name': 'B01',
#        'common_name': 'coastal',
#        'center_wavelength': 0.4439,
#        'full_width_half_max': 0.027}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/B01.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 600000, 0, -60, 3500040, 0, 0, 1]},
#     'B02': {'title': 'Band 2 (blue)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/B02.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 600000, 0, -10, 3500040, 0, 0, 1]},
#     'B03': {'title': 'Band 3 (green)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/B03.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 600000, 0, -10, 3500040, 0, 0, 1]},
#     'B04': {'title': 'Band 4 (red)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/B04.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 600000, 0, -10, 3500040, 0, 0, 1]},
#     'B05': {'title': 'Band 5',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B05',
#        'center_wavelength': 0.7039,
#        'full_width_half_max': 0.019}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/B05.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3500040, 0, 0, 1]},
#     'B06': {'title': 'Band 6',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B06',
#        'center_wavelength': 0.7402,
#        'full_width_half_max': 0.018}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/B06.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3500040, 0, 0, 1]},
#     'B07': {'title': 'Band 7',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B07',
#        'center_wavelength': 0.7825,
#        'full_width_half_max': 0.028}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/B07.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3500040, 0, 0, 1]},
#     'B08': {'title': 'Band 8 (nir)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B08',
#        'common_name': 'nir',
#        'center_wavelength': 0.8351,
#        'full_width_half_max': 0.145}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/B08.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 600000, 0, -10, 3500040, 0, 0, 1]},
#     'B8A': {'title': 'Band 8A',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B8A',
#        'center_wavelength': 0.8648,
#        'full_width_half_max': 0.033}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/B8A.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3500040, 0, 0, 1]},
#     'B09': {'title': 'Band 9',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 60,
#      'eo:bands': [{'name': 'B09',
#        'center_wavelength': 0.945,
#        'full_width_half_max': 0.026}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/B09.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 600000, 0, -60, 3500040, 0, 0, 1]},
#     'B11': {'title': 'Band 11 (swir16)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B11',
#        'common_name': 'swir16',
#        'center_wavelength': 1.6137,
#        'full_width_half_max': 0.143}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/B11.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3500040, 0, 0, 1]},
#     'B12': {'title': 'Band 12 (swir22)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B12',
#        'common_name': 'swir22',
#        'center_wavelength': 2.22024,
#        'full_width_half_max': 0.242}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/B12.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3500040, 0, 0, 1]},
#     'AOT': {'title': 'Aerosol Optical Thickness (AOT)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/AOT.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 600000, 0, -60, 3500040, 0, 0, 1]},
#     'WVP': {'title': 'Water Vapour (WVP)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/WVP.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 600000, 0, -10, 3500040, 0, 0, 1]},
#     'SCL': {'title': 'Scene Classification Map (SCL)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/SCL.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 600000, 0, -20, 3500040, 0, 0, 1]}},
#    'links': [{'rel': 'self',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_14RPV_20220728_0_L2A'},
#     {'rel': 'canonical',
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/S2B_14RPV_20220728_0_L2A.json',
#      'type': 'application/json'},
#     {'title': 'sentinel-s2-l2a-aws/workflow-publish-sentinel/tiles-14-R-PV-2022-7-28-0',
#      'rel': 'via-cirrus',
#      'href': 'https://cirrus-earth-search.aws.element84.com/v0/catid/sentinel-s2-l2a-aws/workflow-publish-sentinel/tiles-14-R-PV-2022-7-28-0'},
#     {'title': 'Source STAC Item',
#      'rel': 'derived_from',
#      'href': 'https://cirrus-v0-data-1qm7gekzjucbq.s3.us-west-2.amazonaws.com/sentinel-s2-l2a/14/R/PV/2022/7/S2B_14RPV_20220728_0_L2A/S2B_14RPV_20220728_0_L2A.json',
#      'type': 'application/json'},
#     {'title': 'sentinel-s2-l2a/workflow-cog-archive/S2B_14RPV_20220728_0_L2A',
#      'rel': 'via-cirrus',
#      'href': 'https://cirrus-earth-search.aws.element84.com/v0/catid/sentinel-s2-l2a/workflow-cog-archive/S2B_14RPV_20220728_0_L2A'},
#     {'rel': 'parent',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'collection',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'root', 'href': 'https://earth-search.aws.element84.com/v0/'}]}]}

# %% [markdown]
# ## Perform a local skim of the data for 1 time slice

# %%
small_data = data.sel(time='2022-07-03').compute()

# %%
# %%time
df = skim(small_data)
df
# Out:
# CPU times: user 164 ms, sys: 45.9 ms, total: 209 ms
# Wall time: 208 ms
#    variables data_types   NaNs         mean          std  maximums  minimums
# 0     visual      uint8  False    83.206896    85.090139       255         0
# 1        B01     uint16  False   694.111545  1057.890177     12671         0
# 2        B02     uint16  False   715.116638  1019.690505     11615         0
# 3        B03     uint16  False   831.311709  1033.465046     10787         0
# 4        B04     uint16  False   897.211163  1064.686861     10284         0
# 5        B05     uint16  False  1144.481014  1258.273113     11399         0
# 6        B06     uint16  False  1453.429606  1447.058901     10691         0
# 7        B07     uint16  False  1585.919234  1543.215470     10361         0
# 8        B08     uint16  False  1592.048660  1549.807719     10519         0
# 9        B8A     uint16  False  1737.786114  1662.727114     10352         0
# 10       B09     uint16  False  2445.116097  3098.090223     15918         0
# 11       B11     uint16  False  1869.718284  1790.813024      8431         0
# 12       B12     uint16  False  1358.351765  1357.018681      8239         0
# 13       AOT     uint16  False    59.987095    57.874945       173         0
# 14       WVP     uint16  False  1847.768434  1681.527584      6201         0
# 15       SCL      uint8  False     3.550229     3.664158        10         0

# %%
gdf = gpd.GeoDataFrame.from_features(stac_json,3857)
gdf
# Out:
#                                              geometry              datetime  \
# 0   POLYGON ((-97.875 28.835, -98.240 28.837, -97....  2022-07-30T17:15:56Z
# 1   POLYGON ((-96.850 28.822, -97.975 28.836, -97....  2022-07-30T17:15:52Z
# 2   POLYGON ((-95.827 28.802, -96.951 28.824, -96....  2022-07-30T17:15:49Z
# 3   POLYGON ((-97.866 29.737, -98.012 29.739, -97....  2022-07-30T17:15:44Z
# 4   POLYGON ((-96.831 29.724, -97.966 29.738, -97....  2022-07-30T17:15:37Z
# ..                                                ...                   ...
# 79  POLYGON ((-97.686 28.835, -97.975 28.836, -97....  2022-07-03T17:25:51Z
# 80  POLYGON ((-97.865 29.737, -99.000 29.742, -99....  2022-07-03T17:25:40Z
# 81  POLYGON ((-97.431 29.734, -97.966 29.739, -97....  2022-07-03T17:25:36Z
# 82  POLYGON ((-97.854 30.640, -99.000 30.645, -99....  2022-07-03T17:25:26Z
# 83  POLYGON ((-97.171 30.633, -97.956 30.642, -97....  2022-07-03T17:25:22Z
#
#        platform constellation instruments  gsd  view:off_nadir  proj:epsg  \
# 0   sentinel-2a    sentinel-2       [msi]   10               0      32614
# 1   sentinel-2a    sentinel-2       [msi]   10               0      32614
# 2   sentinel-2a    sentinel-2       [msi]   10               0      32614
# 3   sentinel-2a    sentinel-2       [msi]   10               0      32614
# 4   sentinel-2a    sentinel-2       [msi]   10               0      32614
# ..          ...           ...         ...  ...             ...        ...
# 79  sentinel-2a    sentinel-2       [msi]   10               0      32614
# 80  sentinel-2a    sentinel-2       [msi]   10               0      32614
# 81  sentinel-2a    sentinel-2       [msi]   10               0      32614
# 82  sentinel-2a    sentinel-2       [msi]   10               0      32614
# 83  sentinel-2a    sentinel-2       [msi]   10               0      32614
#
#     sentinel:utm_zone sentinel:latitude_band sentinel:grid_square  \
# 0                  14                      R                   NT
# 1                  14                      R                   PT
# 2                  14                      R                   QT
# 3                  14                      R                   NU
# 4                  14                      R                   PU
# ..                ...                    ...                  ...
# 79                 14                      R                   PT
# 80                 14                      R                   NU
# 81                 14                      R                   PU
# 82                 14                      R                   NV
# 83                 14                      R                   PV
#
#    sentinel:sequence                                sentinel:product_id  \
# 0                  0  S2A_MSIL2A_20220730T165901_N0400_R069_T14RNT_2...
# 1                  0  S2A_MSIL2A_20220730T165901_N0400_R069_T14RPT_2...
# 2                  0  S2A_MSIL2A_20220730T165901_N0400_R069_T14RQT_2...
# 3                  0  S2A_MSIL2A_20220730T165901_N0400_R069_T14RNU_2...
# 4                  0  S2A_MSIL2A_20220730T165901_N0400_R069_T14RPU_2...
# ..               ...                                                ...
# 79                 0  S2A_MSIL2A_20220703T170901_N0400_R112_T14RPT_2...
# 80                 0  S2A_MSIL2A_20220703T170901_N0400_R112_T14RNU_2...
# 81                 0  S2A_MSIL2A_20220703T170901_N0400_R112_T14RPU_2...
# 82                 0  S2A_MSIL2A_20220703T170901_N0400_R112_T14RNV_2...
# 83                 0  S2A_MSIL2A_20220703T170901_N0400_R112_T14RPV_2...
#
#     sentinel:data_coverage  eo:cloud_cover  sentinel:valid_cloud_cover  \
# 0                    21.79            0.00                        True
# 1                   100.00            8.71                        True
# 2                   100.00           85.35                        True
# 3                     3.91            5.61                        True
# 4                    93.10            2.94                        True
# ..                     ...             ...                         ...
# 79                   37.38           69.16                        True
# 80                  100.00           47.54                        True
# 81                   58.78           16.39                        True
# 82                  100.00           33.68                        True
# 83                   80.12            6.56                        True
#
#    sentinel:processing_baseline  sentinel:boa_offset_applied  \
# 0                         04.00                         True
# 1                         04.00                         True
# 2                         04.00                         True
# 3                         04.00                         True
# 4                         04.00                         True
# ..                          ...                          ...
# 79                        04.00                         True
# 80                        04.00                         True
# 81                        04.00                         True
# 82                        04.00                         True
# 83                        04.00                         True
#
#                      created                   updated
# 0   2022-07-31T19:25:18.048Z  2022-07-31T19:25:18.048Z
# 1   2022-07-31T20:23:18.094Z  2022-07-31T20:23:18.094Z
# 2   2022-07-31T19:51:10.772Z  2022-07-31T19:51:10.772Z
# 3   2022-07-31T20:11:50.723Z  2022-07-31T20:11:50.723Z
# 4   2022-07-31T19:56:23.705Z  2022-07-31T19:56:23.705Z
# ..                       ...                       ...
# 79  2022-07-04T03:04:36.967Z  2022-07-04T03:04:36.967Z
# 80  2022-07-04T03:11:37.286Z  2022-07-04T03:11:37.286Z
# 81  2022-07-04T03:08:20.582Z  2022-07-04T03:08:20.582Z
# 82  2022-07-04T03:08:16.110Z  2022-07-04T03:08:16.110Z
# 83  2022-07-04T03:49:34.629Z  2022-07-04T03:49:34.629Z
#
# [84 rows x 20 columns]

# %%
bbox2 = (gdf.bounds['minx'].min(),gdf.bounds['miny'].min(),gdf.bounds['maxx'].max(),gdf.bounds['maxy'].max())
bbox2
# Out:
# (-99.00020036474238, 28.8021464220105, -95.7356923552778, 31.63553809078258)

# %%
bbox3 = tuple([b+2 for b in bbox2])
bbox3
# Out:
# (-97.00020036474238, 30.8021464220105, -93.7356923552778, 33.635538090782575)

# %%
query(bbox=[bbox,bbox2,bbox3],
                    name=["Query","Returned","Test"],
                    m=folium.Map(),
                    color=["red","green","blue"])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b048eb4eefb90dac47f7123262d4c4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b048eb4eefb90dac47f7123262d4c4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9b048eb4eefb90dac47f7123262d4c4a = L.map(
#                 &quot;map_9b048eb4eefb90dac47f7123262d4c4a&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e6fcc7b113ae2e6524c23e8b373d361 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9b048eb4eefb90dac47f7123262d4c4a);
#
#
#         function geo_json_2ce1e6dc954a6ae2b3748e28682ca285_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fill&quot;: false, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 5};
#             }
#         }
#
#         function geo_json_2ce1e6dc954a6ae2b3748e28682ca285_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2ce1e6dc954a6ae2b3748e28682ca285 = L.geoJson(null, {
#                 onEachFeature: geo_json_2ce1e6dc954a6ae2b3748e28682ca285_onEachFeature,
#
#                 style: geo_json_2ce1e6dc954a6ae2b3748e28682ca285_styler,
#         });
#
#         function geo_json_2ce1e6dc954a6ae2b3748e28682ca285_add (data) {
#             geo_json_2ce1e6dc954a6ae2b3748e28682ca285
#                 .addData(data)
#                 .addTo(map_9b048eb4eefb90dac47f7123262d4c4a);
#         }
#             geo_json_2ce1e6dc954a6ae2b3748e28682ca285_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-96.84309909909909, 29.365099099099098], [-96.84309909909909, 31.1669009009009], [-98.64490090090091, 31.1669009009009], [-98.64490090090091, 29.365099099099098], [-96.84309909909909, 29.365099099099098]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_2ce1e6dc954a6ae2b3748e28682ca285.bindTooltip(
#                 `&lt;div&gt;
#                      Query
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a211449efe62f111ee6cab24932c9f84 = L.marker(
#                 [30.266, -97.744],
#                 {}
#             ).addTo(map_9b048eb4eefb90dac47f7123262d4c4a);
#
#
#             var icon_c639c7fd7d9caadc9b61fe3e8f2f50d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a211449efe62f111ee6cab24932c9f84.setIcon(icon_c639c7fd7d9caadc9b61fe3e8f2f50d1);
#
#
#         var popup_c57105e99f0912875261c631ce29846d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1ee099226d77081ad319df466b5328d2 = $(`&lt;div id=&quot;html_1ee099226d77081ad319df466b5328d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Query Center&lt;/div&gt;`)[0];
#             popup_c57105e99f0912875261c631ce29846d.setContent(html_1ee099226d77081ad319df466b5328d2);
#
#
#         marker_a211449efe62f111ee6cab24932c9f84.bindPopup(popup_c57105e99f0912875261c631ce29846d)
#         ;
#
#
#
#
#         function geo_json_ed5962c7773f1c03d3b84f3be9d225ea_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fill&quot;: false, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 5};
#             }
#         }
#
#         function geo_json_ed5962c7773f1c03d3b84f3be9d225ea_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ed5962c7773f1c03d3b84f3be9d225ea = L.geoJson(null, {
#                 onEachFeature: geo_json_ed5962c7773f1c03d3b84f3be9d225ea_onEachFeature,
#
#                 style: geo_json_ed5962c7773f1c03d3b84f3be9d225ea_styler,
#         });
#
#         function geo_json_ed5962c7773f1c03d3b84f3be9d225ea_add (data) {
#             geo_json_ed5962c7773f1c03d3b84f3be9d225ea
#                 .addData(data)
#                 .addTo(map_9b048eb4eefb90dac47f7123262d4c4a);
#         }
#             geo_json_ed5962c7773f1c03d3b84f3be9d225ea_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-95.7356923552778, 28.8021464220105], [-95.7356923552778, 31.63553809078258], [-99.00020036474238, 31.63553809078258], [-99.00020036474238, 28.8021464220105], [-95.7356923552778, 28.8021464220105]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quo

# %%
B = [bbox,bbox2,bbox3]
N = ["Query","Returned","Test"]
C = ["red","darkblue","cadetblue"]
for (b,n,c) in zip(B,N,C):
    print(f'{b}->{n}->{c}')

# %%
def convert_bounds(bbox, invert_y=False):
    """
    Helper method for changing bounding box representation to leaflet notation

    ``(lon1, lat1, lon2, lat2) -> ((lat1, lon1), (lat2, lon2))``
    """
    x1, y1, x2, y2 = bbox
    if invert_y:
        y1, y2 = y2, y1
    return ((y1, x1), (y2, x2))

def compute_center(bbox):
    x1, y1, x2, y2 = bbox
    mu_x = (x1+x2)/2
    mu_y = (y1+y2)/2
    return (mu_y,mu_x)

map1 = folium.Map()

folium.GeoJson(
    shapely.geometry.box(*bbox),
    style_function=lambda x: dict(fill=False, 
                                  weight=5, 
                                  opacity=0.5, 
                                  color="green"),
    name="Query",
    tooltip="Query",
).add_to(map1)

folium.GeoJson(
    shapely.geometry.box(*bbox2),
    style_function=lambda x: dict(fill=False,
                                  weight=5, 
                                  opacity=0.5, 
                                  color="blue"),
    name="Returned",
    tooltip="Returned",
).add_to(map1)

folium.Marker(compute_center(bbox),
              popup="Query Center",
              icon=folium.Icon(color="green",icon="star")
             ).add_to(map1)
folium.Marker(compute_center(bbox2),
              popup="Return Center",
              icon=folium.Icon(color="blue", icon="star")
             ).add_to(map1)

map1.fit_bounds(bounds=convert_bounds(bbox))

map1

# %%
# Compute granule id from components
gdf["granule"] = (
    gdf["sentinel:utm_zone"].apply(lambda x: f"{x:02d}")
    + gdf["sentinel:latitude_band"]
    + gdf["sentinel:grid_square"]
)

fig = gdf.plot(
    "granule",
    edgecolor="black",
    categorical=True,
    aspect="equal",
    alpha=0.5,
    figsize=(6, 12),
    legend=True,
    legend_kwds={"loc": "upper left", "frameon": False, "ncol": 1},
)
_ = fig.set_title("STAC Query Results")

# %%
# from branca.element import Figure
def convert_bounds(bbox, invert_y=False):
    """
    Helper method for changing bounding box representation to leaflet notation

    ``(lon1, lat1, lon2, lat2) -> ((lat1, lon1), (lat2, lon2))``
    """
    x1, y1, x2, y2 = bbox
    if invert_y:
        y1, y2 = y2, y1
    return ((y1, x1), (y2, x2))

map1 = folium.Map()

folium.GeoJson(
    shapely.geometry.box(*bbox),
    style_function=lambda x: dict(fill=True, weight=1, opacity=0.5, color="green"),
    name="Query",
).add_to(map1)

# folium.GeoJson(
#     shapely.geometry.box(*bbox2),
#     style_function=lambda x: dict(fill=True, weight=1, opacity=0.5, color="blue"),
#     name="Returned",
# ).add_to(map1)
test_bounds = tuple([round(b) for b in bbox])
map1.fit_bounds(bounds=convert_bounds(test_bounds))
# display(fig)
map1

# %%
# Out:
# 2
